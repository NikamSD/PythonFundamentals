# %%
product_description = """Pro-sound Wireless Headphones
Model: WH-200
Features: Bluetooth 5.3, Active Noise Cancellation, 32hrs battery"""

# %%
split_lines = product_description.splitlines()
split_lines
# Out:
# ['Pro-sound Wireless Headphones',
#  'Model: WH-200',
#  'Features: Bluetooth 5.3, Active Noise Cancellation, 32hrs battery']

# %%
capture_first_line = product_description.splitlines()[0].strip().title()
capture_first_line
# Out:
# 'Pro-Sound Wireless Headphones'

# %%
slicing_text = product_description[6:]
print(slicing_text)
# Out:
# und Wireless Headphones
# Model: WH-200
# Features: Bluetooth 5.3, Active Noise Cancellation, 32hrs battery

# %%
reverse_text = product_description[::-1]
reverse_text
# Out:
# 'yrettab srh23 ,noitallecnaC esioN evitcA ,3.5 htooteulB :serutaeF\n002-HW :ledoM\nsenohpdaeH sseleriW dnuos-orP'

# %%
customer = "Avery Sky"

print(f"Right aligned: {customer:>20}")
print(f"Left aligned: {customer:<20}")
print(f"Center aligned: {customer:^20}")
# Out:
# Right aligned:            Avery Sky
# Left aligned: Avery Sky
# Center aligned:      Avery Sky

# %%
fruits = ["apple", "banana", "cherry"]
feature_line =".".join(fruits)
feature_line
# Out:
# 'apple.banana.cherry'

# %%
base = "/home/user"
folder = "documents"
filename = "report.pdf"

file_path = "/".join([base, folder, filename])
print(file_path)
# Out:
# /home/user/documents/report.pdf

# %%
import unicodedata
word = "cafe\u0301"
name = unicodedata.normalize('NFC', word)
print(name)
# Out:
# café

# %%
text = "...,,,,Hello World!!!"
strip_comma_point = text.lstrip(".,")
strip_comma_point
# Out:
# 'Hello World!!!'

# %%
strip_right= text.rstrip("!")
strip_right
# Out:
# '...,,,,Hello World'

# %%
some_value = "  $1,234,567.98   "
cleaned_value = some_value.strip().replace('$','').replace(',','')
print("cleaned_value: ",cleaned_value)

numeric = float(cleaned_value)
print("numeric: ", numeric)
# Out:
# cleaned_value:  1234567.98
# numeric:  1234567.98

# %%
result = product_description.find("Wireless")
result
# Out:
# 10

# %%
new_find = product_description.find("bluetooth")
new_find
# Out:
# -1

# %%
new_find= product_description.lower().find("bluetooth") #-> find() returns the index of the starting letter of the string
print("bluetooth found at index:", new_find)
# Out:
# bluetooth found at index: 54

# %%
print("Does  the product description start with 'bluetooth'? ", product_description.lower().startswith("bluetooth"))
# Out:
# Does  the product description start with 'bluetooth'?  False

# %%
text = "Python is awesome. Python is powerful."
print(f"first python found at index: {text.lower().find('python')}")
print(f"last python found at index: {text.lower().rfind('python')}")
# Out:
# first python found at index: 0
# last python found at index: 19

# %%
text = "SKU: product-123"

print("USe replace: ", text.replace("SKU", "Stock Keeping Unit"))
trans = text.maketrans({" ": "", "-":"_"})
print("Use translate: ", text.translate(trans))
# Out:
# USe replace:  Stock Keeping Unit: product-123
# Use translate:  SKU:product_123

# %%
lines = product_description.splitlines()

features = lines[2].replace("32hrs", "48 hrs").split(", ")
print(features)
# Out:
# ['Features: Bluetooth 5.3', 'Active Noise Cancellation', '48 hrs battery']

# %%
pipe_separated = "| ".join(features)
print(f"pipe separated features- {pipe_separated}")
# Out:
# pipe separated features- Features: Bluetooth 5.3| Active Noise Cancellation| 48 hrs battery

# %%
# Split with maxsplit
url = "https://example.com/api/v1/users/123"

protocol, rest = url.split('://',1)
print(f"protocol: {protocol}, rest: {rest}")
# Out:
# protocol: https, rest: example.com/api/v1/users/123

# %%
# splitlines with different line endings
multiline = "Line1\nLine2\r\nLine3\rLine4"
print(f"\nSplitlines: {multiline.splitlines()}")

# %%
# splitlines with different line endings
multiline = "Line1\nLine2\r\nLine3\rLine4"
print(f"\nSplitlines: {multiline.splitlines()}")
